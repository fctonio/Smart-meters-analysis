# %%
import pandas as pd

# %%
combined_csv = pd.concat([pd.read_csv(f'../Data/hhblock_dataset/block_{i}.csv') for i in range(112)])

# %%
combined_csv
# Out:
#           LCLid         day   hh_0   hh_1   hh_2   hh_3   hh_4   hh_5   hh_6  \
# 0     MAC000002  2012-10-13  0.263  0.269  0.275  0.256  0.211  0.136  0.161
# 1     MAC000002  2012-10-14  0.262  0.166  0.226  0.088  0.126  0.082  0.123
# 2     MAC000002  2012-10-15  0.192  0.097  0.141  0.083  0.132  0.070  0.130
# 3     MAC000002  2012-10-16  0.237  0.237  0.193  0.118  0.098  0.107  0.094
# 4     MAC000002  2012-10-17  0.157  0.211  0.155  0.169  0.101  0.117  0.084
# ...         ...         ...    ...    ...    ...    ...    ...    ...    ...
# 9735  MAC004828  2014-02-23  0.000  0.040  0.018  0.000  0.000  0.036  0.021
# 9736  MAC004828  2014-02-24  0.000  0.000  0.022  0.036  0.000  0.000  0.014
# 9737  MAC004828  2014-02-25  0.022  0.000  0.000  0.034  0.028  0.040  0.051
# 9738  MAC004828  2014-02-26  0.000  0.044  0.015  0.000  0.000  0.031  0.027
# 9739  MAC004828  2014-02-27  0.000  0.021  0.036  0.000  0.000  0.024  0.032
#
# ...

# %%
info_csv = pd.read_csv('../Data/informations_households.csv')

# %%
merged_csv = combined_csv.merge(info_csv, on = 'LCLid')

# %%
merged_csv
# Out:
#              LCLid         day   hh_0   hh_1   hh_2   hh_3   hh_4   hh_5  \
# 0        MAC000002  2012-10-13  0.263  0.269  0.275  0.256  0.211  0.136
# 1        MAC000002  2012-10-14  0.262  0.166  0.226  0.088  0.126  0.082
# 2        MAC000002  2012-10-15  0.192  0.097  0.141  0.083  0.132  0.070
# 3        MAC000002  2012-10-16  0.237  0.237  0.193  0.118  0.098  0.107
# 4        MAC000002  2012-10-17  0.157  0.211  0.155  0.169  0.101  0.117
# ...            ...         ...    ...    ...    ...    ...    ...    ...
# 3469347  MAC004828  2014-02-23  0.000  0.040  0.018  0.000  0.000  0.036
# 3469348  MAC004828  2014-02-24  0.000  0.000  0.022  0.036  0.000  0.000
# 3469349  MAC004828  2014-02-25  0.022  0.000  0.000  0.034  0.028  0.040
# 3469350  MAC004828  2014-02-26  0.000  0.044  0.015  0.000  0.000  0.031
# 3469351  MAC004828  2014-02-27  0.000  0.021  0.036  0.000  0.000  0.024
#
#           hh_6   hh_7  ...  hh_42  hh_43  hh_44  hh_45  hh_46  hh_47  \
# ...

# %%
merged_csv.loc[merged_csv['Acorn'] == 'ACORN-U']
# Out:
#              LCLid         day   hh_0   hh_1   hh_2   hh_3   hh_4   hh_5  \
# 3431652  MAC000099  2011-12-13  0.130  0.105  0.081  0.079  0.022  0.020
# 3431653  MAC000099  2011-12-14  0.110  0.218  0.202  0.140  0.130  0.130
# 3431654  MAC000099  2011-12-15  0.081  0.079  0.117  0.125  0.068  0.027
# 3431655  MAC000099  2011-12-16  0.072  0.090  0.101  0.131  0.091  0.071
# 3431656  MAC000099  2011-12-17  0.101  0.102  0.233  0.101  0.079  0.078
# ...            ...         ...    ...    ...    ...    ...    ...    ...
# 3469347  MAC004828  2014-02-23  0.000  0.040  0.018  0.000  0.000  0.036
# 3469348  MAC004828  2014-02-24  0.000  0.000  0.022  0.036  0.000  0.000
# 3469349  MAC004828  2014-02-25  0.022  0.000  0.000  0.034  0.028  0.040
# 3469350  MAC004828  2014-02-26  0.000  0.044  0.015  0.000  0.000  0.031
# 3469351  MAC004828  2014-02-27  0.000  0.021  0.036  0.000  0.000  0.024
#
#           hh_6   hh_7  ...  hh_42  hh_43  hh_44  hh_45  hh_46  hh_47  \
# ...

# %%
merged_csv = merged_csv.groupby(by ='Acorn').mean().reset_index()

# %%
merged_csv
# Out:
#       Acorn      hh_0      hh_1      hh_2      hh_3      hh_4      hh_5  \
# 0    ACORN-  0.188946  0.178834  0.165649  0.147394  0.127520  0.125931
# 1   ACORN-A  0.310594  0.275233  0.249999  0.233997  0.223660  0.217964
# 2   ACORN-B  0.176595  0.153550  0.135713  0.127037  0.122915  0.123745
# 3   ACORN-C  0.180511  0.156411  0.140311  0.129169  0.121903  0.117881
# 4   ACORN-D  0.215055  0.188244  0.168507  0.156437  0.147990  0.143163
# 5   ACORN-E  0.194509  0.188161  0.169465  0.153901  0.142367  0.135577
# 6   ACORN-F  0.156744  0.140010  0.128291  0.118938  0.111147  0.105000
# 7   ACORN-G  0.165387  0.150853  0.135291  0.125210  0.117683  0.112944
# 8   ACORN-H  0.171134  0.151252  0.135965  0.123986  0.117435  0.114038
# 9   ACORN-I  0.137267  0.121608  0.111217  0.104484  0.101162  0.099284
# 10  ACORN-J  0.297431  0.351587  0.283006  0.227479  0.183559  0.164568
# 11  ACORN-K  0.164674  0.145681  0.131373  0.120934  0.113635  0.108228
# ...

# %%
merged_csv.to_csv("../Data/hh_consumption.csv")
